# %%
import pandas as pd

# %%
df=pd.read_csv('d:\Z-Games/furniture retail analysis\online_furniture_retailer.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\micro\AppData\Local\Temp\ipykernel_7676\788709921.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   df=pd.read_csv('d:\Z-Games/furniture retail analysis\online_furniture_retailer.csv')

# %%
df.head()
# Out:
#   product_category product_subcategory             brand  delivery_status  \
# 0          Outdoor           Patio Set      World Market  Failed Delivery
# 1      Living Room                Sofa          West Elm        Cancelled
# 2      Dining Room           Bar Stool  Ashley Furniture        Delivered
# 3      Dining Room       China Cabinet         HomeGoods          Pending
# 4      Dining Room       China Cabinet               CB2          Pending
#
#    assembly_service_requested    payment_method  order_id  customer_id  \
# 0                        True       Credit Card     93810         2824
# 1                        True         Apple Pay     13278         5506
# 2                       False  Cash on Delivery     42098         4657
# 3                       False        Google Pay     28289         2679
# 4                        True         Apple Pay     98696         9935
#
#    product_price  shipping_cost  assembly_cost  total_amount  \
# ...

# %%
df.columns=(df.columns.str.replace("_"," ").str.capitalize())
df['Customer rating']=df["Customer rating"].fillna(int(df["Customer rating"].mean()))
for col in df.select_dtypes('object'):
    df[col]=df[col].str.capitalize().str.replace("/.,\-_';[]()"," ").str.strip()
df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\-'
# <>:4: SyntaxWarning: invalid escape sequence '\-'
# C:\Users\micro\AppData\Local\Temp\ipykernel_7676\3473449724.py:4: SyntaxWarning: invalid escape sequence '\-'
#   df[col]=df[col].str.capitalize().str.replace("/.,\-_';[]()"," ").str.strip()
#   Product category Product subcategory             Brand  Delivery status  \
# 0          Outdoor           Patio set      World market  Failed delivery
# 1      Living room                Sofa          West elm        Cancelled
# 2      Dining room           Bar stool  Ashley furniture        Delivered
# 3      Dining room       China cabinet         Homegoods          Pending
# 4      Dining room       China cabinet               Cb2          Pending
#
#    Assembly service requested    Payment method  Order id  Customer id  \
# 0                        True       Credit card     93810         2824
# 1                        True         Apple pay     13278         5506
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1938 entries, 0 to 1937
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Product category            1938 non-null   object
#  1   Product subcategory         1938 non-null   object
#  2   Brand                       1842 non-null   object
#  3   Delivery status             1938 non-null   object
#  4   Assembly service requested  1938 non-null   bool
#  5   Payment method              1938 non-null   object
#  6   Order id                    1938 non-null   int64
#  7   Customer id                 1938 non-null   int64
#  8   Product price               1938 non-null   float64
#  9   Shipping cost               1880 non-null   float64
#  10  Assembly cost               1900 non-null   float64
#  11  Total amount                1938 non-null   float64
#  12  Delivery window days        1938 non-null   int64
# ...

# %%
df.to_csv("online_furniture_retailer for BI")
